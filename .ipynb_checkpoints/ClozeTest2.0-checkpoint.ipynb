# %%
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import glob 
import json
import re
import string
import operator
import collections
import numpy as np
import string
import math
from tqdm import tqdm
from array import array
import pandas as pd

# %%
NONE_STR = '<s>'

# %%
def delete_other_letter(line):
    punctuation ="""!"#$%&\()*+,./:;<=>?@[\\]^_`{|}~\\n"""
    re_punctuation ="[{}]+".format(punctuation)
    line =re.sub(re_punctuation, "", line)
    return line.lower()

# %%
def read_articles(paths):
    alllines = []
    for path in paths:
        filenames = glob.glob(path+"/*txt")
        for filename in filenames:
            with open(filename, 'r', encoding='utf-8') as fpr:
                data_raw = json.load(fpr)
                article = data_raw['article']
                
                lines = article.split('.')
                for line in lines:
                    line = delete_other_letter(line)
                    alllines.append(line)
                
    return alllines

# %%
lines = read_articles(['./RACE/train/high','./RACE/train/middle'])

# %%
print(len(lines))
# Out:
# 499388

# %%
# def word_dict(lines):
#     word_freq = collections.defaultdict(int)
#     for line in lines:
#         for w in line.split(): 
#             word_freq[w] += 1
    
#     return list(word_freq.keys())

# %%
# def get_words_matrix(words,lines):                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               
#     for line in lines:
#         line_words = line.split()
#         n = len(line_words)
#         for i in range(n-1):
#             ww = line_words[i+1]
#             i = words.index(line_words[i])
#             j = words.index(ww)
#             words_matrix[i][j] += 1

# %%
def word_dict(lines,n):
                
    pre_words = collections.defaultdict(int)
    be_words = collections.defaultdict(int)
    n = n-1
    for line in lines:
        for k in range(n):
            line = NONE_STR+' '+line+' '+NONE_STR
        line_words = line.split()
        for i in range(len(line_words)-(n-1)):
            ngramTemp = ' '.join(line_words[i:i+n])

            pre_words[ngramTemp] += 1
            be_words[line_words[i]] += 1
            
    return pre_words,be_words

# %%
def replace_punctuation(word):
    for puc in punctuation_list:
        word = word.replace(puc,'')
    return word

# %%
def replace_Chinese_punctuation(content):
    content = content.replace('’','\'')
    content = content.replace('”','')
    return content

# %%
def get_options(options_str):
    options_str = replace_Chinese_punctuation(options_str)
    options = []
    opt_rows = options_str.split('#')
    for opt in opt_rows:
        indexA = opt.find('A.')
        indexB = opt.find('B.')
        indexC = opt.find('C.')
        indexD = opt.find('D.')
        As = opt[indexA+2:indexB].strip().lower().split(' ')
        Bs = opt[indexB+2:indexC].strip().lower().split(' ')
        Cs = opt[indexC+2:indexD].strip().lower().split(' ')
        Ds = opt[indexD+2:].strip().lower().split(' ')
        options.append([As,Bs,Cs,Ds])
    return options

# %%
# def probability(word1,word2):
#     eclipse = 0.0000000000001
#     try:
#         index1 = pre_words.index(word1)
#         index2 = be_words.index(word2)
#     except ValueError:
#         return eclipse
# #     print(word1,index1,word2,index2)
#     pn_word1 = words_matrix[index1].sum()
#     pn_word2_under_word1 = words_matrix[index1][index2]
# #     print(pn_word1,pn_word2_under_word1)
#     prob = float(pn_word2_under_word1)/pn_word1
#     if prob == 0:
#         prob = eclipse
#     return prob

# %%
def read_train_data(n):
    path = './data'
    filenames = glob.glob(path+"/*txt")
    
    answers_list =[]
    options_list = []
    content_list = []
    for filename in filenames:
        with open(filename, 'r', encoding='utf-8') as fpr:
            data_raw = json.load(fpr)
            article = data_raw['article']
            content = get_pre_and_be_words(article,n)
            options_str = data_raw['options']
            options = get_options(options_str)
            answers = list(data_raw['answers'])
            answers_list.append(answers)
            options_list.append(options)
            content_list.append(content)
    return content_list,options_list,answers_list

# %%
def test(content_list,options_list,answers_list,ngram,showAll=False,predict=None):
    
    cn = len(content_list)
    right_n = 0
    total_n = 0
    for k in range(cn):
        content = content_list[k]
        answers = answers_list[k]
        options = options_list[k]
    
        n = len(answers)
        total_n += n
        for i in range(n):
            if showAll:
                print('---------'+str(i+1)+'---------')
            if predict is None:
#                 print('before:',content[i])
                choice = auto_select(content[i],options[i],ngram)
#                 print('after:',content[i])
            else:
                choice = predict
            if choice == answers[i]:
                right_n += 1
                if showAll == False:
                    print('---------'+str(i+1)+'---------')
                    print('predict:',choice,'ground truth:',answers[i])
                    print('空前后的词',content[i])
                    print('选项',options[i])
            if showAll:
                print('predict:',choice,'ground truth:',answers[i])
                print('空前后的词',content[i])
                print('选项',options[i])
    accuracy = float(right_n)/total_n
    print('accuracy:',accuracy)

# %%
def get_words_matrix(pre_words,be_words,lines,n):  
    n = n-1
    for line in tqdm(lines):
        for k in range(n):
            line = NONE_STR+' '+line+' '+NONE_STR
        line_words = line.split()
        words_n = len(line_words)-n
        for k in range(words_n):
            pre_word = ' '.join(line_words[k:k+n])
                
            be_word = line_words[k+n]
            
            if pre_word in pre_words and be_word in be_words:
                i = pre_words.index(pre_word)
                j = be_words.index(be_word)
                words_matrix[i][j] += 1
                    
#             if n > 1:
#                 if pre_word in pre_words:
#                     i = pre_words.index(pre_word)
#                     j = be_words.index(be_word)
#                     words_matrix[i][j] += 1
#             else:
#                 i = pre_words.index(pre_word)
#                 j = be_words.index(be_word)
#                 words_matrix[i][j] += 1
            
    return words_matrix

# %%
def count_word_num(lines,n):
    pre_words = collections.defaultdict(int)
    be_words = collections.defaultdict(int)
    
    words = collections.defaultdict(int)
    n = n-1
    
    index = 0
    for line in lines:
        for k in range(n):
            line = NONE_STR+' '+line+' '+NONE_STR
        line_words = line.split()
        for i in range(len(line_words)-(n-1)):
            pre_word = ' '.join(line_words[i-1:i+n-1])
            be_word = line_words[i+n-1]
            
            pre_words[pre_word] += 1
            be_words[be_word] += 1
            
            words[pre_word+' '+be_word] += 1
    return pre_words,be_words,words

# %%
punctuation_list = ['.',',','?','!','\"','“']

# %%
def check_punctuation_and_replace_with_none(word_list,reverse = False):
    n = len(word_list)
    f_flag = False #第一个字符是否为标点
    b_flag = False #最后一个字符是否为标点
    if reverse == True:
        for i in range(n-1, -1, -1):
            word = word_list[i]
            if b_flag == False:
                for puc in punctuation_list:
                    if word[-1]==puc :
                        b_flag = True 
                        break
                    elif word[0] == puc:
                        f_flag = True
                        break
            if b_flag == True:
                word_list[i] = NONE_STR
            else:
                word_list[i] = replace_punctuation(word).lower()
            if f_flag == True:
                b_flag = True
    else:
        for i in range(n):
            word = word_list[i]
            if f_flag == False:
                for puc in punctuation_list:
                    if word[0] == puc:
                        f_flag = True
                        break
                    elif word[-1]==puc :
                        b_flag = True 
                        break
            if f_flag == True:
                word_list[i] = NONE_STR
            else:
                word_list[i] = replace_punctuation(word).lower()
            if b_flag == True:
                f_flag = True
    return word_list

# %%
def get_pre_and_be_words(article,ngram):
    article = replace_Chinese_punctuation(article)
    art_words = article.split()
    n = len(art_words)
    index = 1
    content = []
    for i in range(n):
        word = art_words[i]
        if str(index) == word:
            pre_word_list = []
            be_word_list = []
            if i < ngram-1:
                for k in range(ngram-1-i):
                    pre_word_list.append(NONE_STR)
            else:
                pre_word_list = art_words[i-1-(ngram-2):i]
            pre_word_list = check_punctuation_and_replace_with_none(pre_word_list,True)

            if i > n-ngram:
                for k in range(ngram-1-(n-ngram)):
                    be_word_list.append(NONE_STR)
            else:
                be_word_list = art_words[i+1:i+1+ngram-1]
            be_word_list = check_punctuation_and_replace_with_none(be_word_list,False)
            
            content.append([pre_word_list,be_word_list])
            index += 1
    return content

# %%
def delete_sparse_words(words_dict,threshold=4):
    words_list = []
    for key, value in words_dict.items():
        if value > 4:
            words_list.append(key)
    return words_list

# %%
def probability(word1,word2):
    eclipse = 0.0000000000001
    all = pre_words[word1]
    single = words[word1+' '+word2]
    
    if all == 0:
        return eclipse
    
    prob = float(single)/all
    if prob == 0:
        prob = eclipse
        
    return prob

# %% [markdown]
# <font color=blue size=15 face=雅黑>bigram Test</font>

# %%
pre_words,be_words,words = count_word_num(lines,2)

# %%
content_list,options_list,answers_list = read_train_data(2)

# %%
print(content_list[0])
# Out:
# [[["i'd"], ['seen']], [['my'], ['when']], [['was'], ['<s>']], [['to'], ['<s>']], [['was'], ['in']], [['little'], ['<s>']], [['in'], ['<s>']], [['not'], ['<s>']], [['and'], ['into']], [['was'], ['violently']], [['helped'], ['the']], [['something'], ['to']], [['very'], ['<s>']], [['i'], ['<s>']], [['<s>'], ['<s>']], [['to'], ['and']], [['ben'], ['to']], [['you'], ['my']], [['a'], ['it']], [['there'], ['to']]]

# %%
print(options_list[0])
# Out:
# [[['also'], ['often'], ['even'], ['last']], [['delight'], ['relief'], ['anger'], ['worry']], [['scared'], ['shocked'], ['thrilled'], ['ashamed']], [['talk'], ['stay'], ['meet'], ['settle']], [['bathed'], ['clean'], ['deep'], ['formed']], [['faster'], ['closer'], ['heavier'], ['wiser']], [['trouble'], ['advance'], ['question'], ['battle']], [['real'], ['right'], ['fair'], ['fit']], [['stared'], ['sank'], ['dived'], ['fell']], [['arguing'], ['fighting'], ['shouting'], ['shaking']], [['lead'], ['persuade'], ['carry'], ['keep']], [['happened'], ['occurred'], ['applied'], ['appealed']], [['sharp'], ['pleasant'], ['attractive'], ['familiar']], [['agreed'], ['hesitated'], ['doubted'], ['knew']], [['fortunately'], ['frankly'], ['sadly'], ['suddenly']], [['return'], ['relax'], ['speak'], ['leave']], [['joked'], ['turned'], ['listened'], ['pointed']], [['created'], ['honored'], ['saved'], ['guided']], [['coincidence'], ['change'], ['pity'], ['pain']], [['on', 'board'], ['in', 'time'], ['for', 'sure'], ['on', 'purpose']]]

# %%
print(answers_list[0])
# Out:
# ['D', 'A', 'C', 'C', 'A', 'B', 'A', 'B', 'C', 'D', 'C', 'B', 'D', 'D', 'A', 'D', 'B', 'C', 'A', 'B']

# %% [markdown]
# <font color=black size=5 face=雅黑>全选A/B/C/D 观察正确率</font>

# %%
test(content_list,options_list,answers_list,2,showAll=False,predict='A')
# Out:
# ---------2---------
# predict: A ground truth: A
# 空前后的词 [['my'], ['when']]
# 选项 [['delight'], ['relief'], ['anger'], ['worry']]
# ---------5---------
# predict: A ground truth: A
# 空前后的词 [['was'], ['in']]
# 选项 [['bathed'], ['clean'], ['deep'], ['formed']]
# ---------7---------
# predict: A ground truth: A
# 空前后的词 [['in'], ['<s>']]
# 选项 [['trouble'], ['advance'], ['question'], ['battle']]
# ---------15---------
# predict: A ground truth: A
# 空前后的词 [['<s>'], ['<s>']]
# 选项 [['fortunately'], ['frankly'], ['sadly'], ['suddenly']]
# ---------19---------
# predict: A ground truth: A
# 空前后的词 [['a'], ['it']]
# 选项 [['coincidence'], ['change'], ['pity'], ['pain']]
# ---------5---------
# predict: A ground truth: A
# 空前后的词 [['could'], ['that']]
# 选项 [['see'], ['find'], ['guess'], ['learn']]
# ---------8---------
# predict: A ground truth: A
# 空前后的词 [['i'], ['each']]
# 选项 [['chatted', 'with'], ['looked', 'at'], ['laughed', 'at'], ['talked', 'about']]
# ---------12---------
# predict: A ground truth: A
# 空前后的词 [['and'], ['without']]
# 选项 [['left'], ['acted'], ['sat', 'down'], ['calmed', 'down']]
# ---------13---------
# predict: A ground truth: A
# 空前后的词 [['had'], ['<s>']]
# 选项 [['wanted'], ['tried'], ['ordered'], ['wished']]
# ---------17---------
# predict: A ground truth: A
# 空前后的词 [['i'], ['say']]
# 选项 [['must'], ['can'], ['need'], ['may']]
# ---------3---------
# predict: A ground truth: A
# 空前后的词 [["weren't"], ['enough']]
# 选项 [['excited'], ['worried'], ['moved'], ['tired']]
# ---------12---------
# predict: A ground truth: A
# 空前后的词 [['<s>'], ['<s>']]
# 选项 [['eventually'], ['naturally'], ['directly'], ['normally']]
# ---------15---------
# predict: A ground truth: A
# 空前后的词 [['he'], ['me']]
# 选项 [['taught'], ['wrote'], ['questioned'], ['promised']]
# ---------18---------
# predict: A ground truth: A
# 空前后的词 [['to'], ['a']]
# 选项 [['analyze'], ['describe'], ['rebuild'], ['control']]
# ---------20---------
# predict: A ground truth: A
# 空前后的词 [['my'], ['as']]
# 选项 [['role'], ['desire'], ['concern'], ['behavior']]
# accuracy: 0.25

# %%
test(content_list,options_list,answers_list,2,showAll=False,predict='B')
# Out:
# ---------6---------
# predict: B ground truth: B
# 空前后的词 [['little'], ['<s>']]
# 选项 [['faster'], ['closer'], ['heavier'], ['wiser']]
# ---------8---------
# predict: B ground truth: B
# 空前后的词 [['not'], ['<s>']]
# 选项 [['real'], ['right'], ['fair'], ['fit']]
# ---------12---------
# predict: B ground truth: B
# 空前后的词 [['something'], ['to']]
# 选项 [['happened'], ['occurred'], ['applied'], ['appealed']]
# ---------17---------
# predict: B ground truth: B
# 空前后的词 [['ben'], ['to']]
# 选项 [['joked'], ['turned'], ['listened'], ['pointed']]
# ---------20---------
# predict: B ground truth: B
# 空前后的词 [['there'], ['to']]
# 选项 [['on', 'board'], ['in', 'time'], ['for', 'sure'], ['on', 'purpose']]
# ---------3---------
# predict: B ground truth: B
# 空前后的词 [['newspaper'], ['in']]
# 选项 [['flat'], ['open'], ['cut'], ['fixed']]
# ---------7---------
# predict: B ground truth: B
# 空前后的词 [['the'], ['way']]
# 选项 [['direct'], ['familiar'], ['strange'], ['funny']]
# ---------9---------
# predict: B ground truth: B
# 空前后的词 [['as'], ['went']]
# 选项 [['the', 'waiter'], ['time'], ['i'], ['the', 'dinner']]
# ---------16---------
# predict: B ground truth: B
# 空前后的词 [['my'], ['<s>']]
# 选项 [['care'], ['surprise'], ['worry'], ['regret']]
# ---------18---------
# predict: B ground truth: B
# 空前后的词 [['a'], ['<s>']]
# 选项 [['discovery'], ['mistake'], ['decision'], ['fortune']]
# ---------1---------
# predict: B ground truth: B
# 空前后的词 [['i'], ['the']]
# 选项 [['put', 'forward'], ['jumped', 'at'], ['tried', 'out'], ['turned', 'down']]
# ---------7---------
# predict: B ground truth: B
# 空前后的词 [['to'], ['him']]
# 选项 [['interview'], ['meet'], ['challenge'], ['beat']]
# ---------10---------
# predict: B ground truth: B
# 空前后的词 [['to'], ['the']]
# 选项 [['attend'], ['pass'], ['skip'], ['observe']]
# ---------14---------
# predict: B ground truth: B
# 空前后的词 [['the'], ['<s>']]
# 选项 [['criterion'], ['classroom'], ['department'], ['situation']]
# ---------17---------
# predict: B ground truth: B
# 空前后的词 [['good'], ['<s>']]
# 选项 [['grades'], ['decisions'], ['impressions'], ['comments']]
# accuracy: 0.25

# %%
test(content_list,options_list,answers_list,2,showAll=False,predict='C')
# Out:
# ---------3---------
# predict: C ground truth: C
# 空前后的词 [['was'], ['<s>']]
# 选项 [['scared'], ['shocked'], ['thrilled'], ['ashamed']]
# ---------4---------
# predict: C ground truth: C
# 空前后的词 [['to'], ['<s>']]
# 选项 [['talk'], ['stay'], ['meet'], ['settle']]
# ---------9---------
# predict: C ground truth: C
# 空前后的词 [['and'], ['into']]
# 选项 [['stared'], ['sank'], ['dived'], ['fell']]
# ---------11---------
# predict: C ground truth: C
# 空前后的词 [['helped'], ['the']]
# 选项 [['lead'], ['persuade'], ['carry'], ['keep']]
# ---------18---------
# predict: C ground truth: C
# 空前后的词 [['you'], ['my']]
# 选项 [['created'], ['honored'], ['saved'], ['guided']]
# ---------1---------
# predict: C ground truth: C
# 空前后的词 [['i'], ['that']]
# 选项 [['knew'], ['understood'], ['noticed'], ['recognized']]
# ---------4---------
# predict: C ground truth: C
# 空前后的词 [['was'], ['to']]
# 选项 [['hoping'], ['thinking'], ['pretending'], ['continuing']]
# ---------10---------
# predict: C ground truth: C
# 空前后的词 [['became'], ['that']]
# 选项 [['true'], ['hopeful'], ['clear'], ['possible']]
# ---------14---------
# predict: C ground truth: C
# 空前后的词 [['he'], ['you']]
# 选项 [['met'], ['caught'], ['followed'], ['discovered']]
# ---------20---------
# predict: C ground truth: C
# 空前后的词 [['<s>'], ['<s>']]
# 选项 [['thus'], ['however'], ['otherwise'], ['therefore']]
# ---------2---------
# predict: C ground truth: C
# 空前后的词 [['to'], ['a']]
# 选项 [['waste'], ['earn'], ['save'], ['pay']]
# ---------6---------
# predict: C ground truth: C
# 空前后的词 [["game's"], ['<s>']]
# 选项 [['fastest'], ['easiest'], ['best'], ['rarest']]
# ---------9---------
# predict: C ground truth: C
# 空前后的词 [['it'], ['that']]
# 选项 [['real'], ['perfect'], ['clear'], ['possible']]
# ---------11---------
# predict: C ground truth: C
# 空前后的词 [['to'], ['what']]
# 选项 [['add'], ['expose'], ['apply'], ['compare']]
# ---------13---------
# predict: C ground truth: C
# 空前后的词 [['that'], ['and']]
# 选项 [['game'], ['presentation'], ['course'], ['experiment']]
# accuracy: 0.25

# %%
test(content_list,options_list,answers_list,2,showAll=False,predict='D')
# Out:
# ---------1---------
# predict: D ground truth: D
# 空前后的词 [["i'd"], ['seen']]
# 选项 [['also'], ['often'], ['even'], ['last']]
# ---------10---------
# predict: D ground truth: D
# 空前后的词 [['was'], ['violently']]
# 选项 [['arguing'], ['fighting'], ['shouting'], ['shaking']]
# ---------13---------
# predict: D ground truth: D
# 空前后的词 [['very'], ['<s>']]
# 选项 [['sharp'], ['pleasant'], ['attractive'], ['familiar']]
# ---------14---------
# predict: D ground truth: D
# 空前后的词 [['i'], ['<s>']]
# 选项 [['agreed'], ['hesitated'], ['doubted'], ['knew']]
# ---------16---------
# predict: D ground truth: D
# 空前后的词 [['to'], ['and']]
# 选项 [['return'], ['relax'], ['speak'], ['leave']]
# ---------2---------
# predict: D ground truth: D
# 空前后的词 [['<s>'], ['he']]
# 选项 [['since'], ['even', 'if'], ['though'], ['as', 'if']]
# ---------6---------
# predict: D ground truth: D
# 空前后的词 [['my'], ['the']]
# 选项 [['menu'], ['bill'], ['paper'], ['food']]
# ---------11---------
# predict: D ground truth: D
# 空前后的词 [['the'], ['<s>']]
# 选项 [['restaurant'], ['washroom'], ['office'], ['kitchen']]
# ---------15---------
# predict: D ground truth: D
# 空前后的词 [['he'], ['<s>']]
# 选项 [['was', 'to', 'beat'], ['was', 'dealing', 'with'], ['was', 'to', 'meet'], ['was', 'looking', 'for']]
# ---------19---------
# predict: D ground truth: D
# 空前后的词 [['really'], ['i']]
# 选项 [['a', 'pity'], ['natural'], ['a', 'chance'], ['lucky']]
# ---------4---------
# predict: D ground truth: D
# 空前后的词 [['our'], ['was']]
# 选项 [['title'], ['competitor'], ['textbook'], ['instructor']]
# ---------5---------
# predict: D ground truth: D
# 空前后的词 [['which'], ['i']]
# 选项 [['urged'], ['demanded'], ['held'], ['meant']]
# ---------8---------
# predict: D ground truth: D
# 空前后的词 [['this'], ['was']]
# 选项 [['chance'], ['qualification'], ['honor'], ['job']]
# ---------16---------
# predict: D ground truth: D
# 空前后的词 [['important'], ['that']]
# 选项 [['fact'], ['step'], ['manner'], ['skill']]
# ---------19---------
# predict: D ground truth: D
# 空前后的词 [['and'], ['the']]
# 选项 [['announce'], ['signal'], ['block'], ['evaluate']]
# accuracy: 0.25

# %% [markdown]
# <font color=black size=5 face=雅黑>采用bigram模型后，正确率</font>

# %%
def auto_select(question,option,ngram):
    index = 0
    maxprob = -10000000000
    n = len(option)
    for i in range(n):
        word_list = []
        word_list = question[0].copy()
        word_list.append(option[i][0])
        word_list.extend(question[1])
        wln = len(word_list)
        prob = 0
        for k in range(wln-ngram+1):
            pre_word = ' '.join(word_list[k:k+ngram-1])
            prob += math.log(probability(pre_word,word_list[k+ngram-1]))
        if prob > maxprob:
            maxprob = prob
            index = i
    return chr(ord('A')+index)

# %%
print(content_list[0])
# Out:
# [[["i'd"], ['seen']], [['my'], ['when']], [['was'], ['<s>']], [['to'], ['<s>']], [['was'], ['in']], [['little'], ['<s>']], [['in'], ['<s>']], [['not'], ['<s>']], [['and'], ['into']], [['was'], ['violently']], [['helped'], ['the']], [['something'], ['to']], [['very'], ['<s>']], [['i'], ['<s>']], [['<s>'], ['<s>']], [['to'], ['and']], [['ben'], ['to']], [['you'], ['my']], [['a'], ['it']], [['there'], ['to']]]

# %%
test(content_list,options_list,answers_list,2,showAll=True)
# Out:
# ---------1---------
# predict: B ground truth: D
# 空前后的词 [["i'd"], ['seen']]
# 选项 [['also'], ['often'], ['even'], ['last']]
# ---------2---------
# predict: A ground truth: A
# 空前后的词 [['my'], ['when']]
# 选项 [['delight'], ['relief'], ['anger'], ['worry']]
# ---------3---------
# predict: B ground truth: C
# 空前后的词 [['was'], ['<s>']]
# 选项 [['scared'], ['shocked'], ['thrilled'], ['ashamed']]
# ---------4---------
# predict: A ground truth: C
# 空前后的词 [['to'], ['<s>']]
# 选项 [['talk'], ['stay'], ['meet'], ['settle']]
# ---------5---------
# predict: D ground truth: A
# 空前后的词 [['was'], ['in']]
# 选项 [['bathed'], ['clean'], ['deep'], ['formed']]
# ---------6---------
# predict: A ground truth: B
# 空前后的词 [['little'], ['<s>']]
# 选项 [['faster'], ['closer'], ['heavier'], ['wiser']]
# ---------7---------
# predict: B ground truth: A
# 空前后的词 [['in'], ['<s>']]
# 选项 [['trouble'], ['advance'], ['question'], ['battle']]
# ---------8---------
# predict: C ground truth: B
# 空前后的词 [['not'], ['<s>']]
# 选项 [['real'], ['right'], ['fair'], ['fit']]
# ---------9---------
# predict: D ground truth: C
# 空前后的词 [['and'], ['into']]
# 选项 [['stared'], ['sank'], ['dived'], ['fell']]
# ---------10---------
# predict: D ground truth: D
# 空前后的词 [['was'], ['violently']]
# 选项 [['arguing'], ['fighting'], ['shouting'], ['shaking']]
# ---------11---------
# predict: D ground truth: C
# 空前后的词 [['helped'], ['the']]
# 选项 [['lead'], ['persuade'], ['carry'], ['keep']]
# ---------12---------
# predict: A ground truth: B
# 空前后的词 [['something'], ['to']]
# 选项 [['happened'], ['occurred'], ['applied'], ['appealed']]
# ---------13---------
# predict: C ground truth: D
# 空前后的词 [['very'], ['<s>']]
# 选项 [['sharp'], ['pleasant'], ['attractive'], ['familiar']]
# ---------14---------
# predict: D ground truth: D
# 空前后的词 [['i'], ['<s>']]
# 选项 [['agreed'], ['hesitated'], ['doubted'], ['knew']]
# ---------15---------
# predict: D ground truth: A
# 空前后的词 [['<s>'], ['<s>']]
# 选项 [['fortunately'], ['frankly'], ['sadly'], ['suddenly']]
# ---------16---------
# predict: B ground truth: D
# 空前后的词 [['to'], ['and']]
# 选项 [['return'], ['relax'], ['speak'], ['leave']]
# ---------17---------
# predict: C ground truth: B
# 空前后的词 [['ben'], ['to']]
# 选项 [['joked'], ['turned'], ['listened'], ['pointed']]
# ---------18---------
# predict: C ground truth: C
# 空前后的词 [['you'], ['my']]
# 选项 [['created'], ['honored'], ['saved'], ['guided']]
# ---------19---------
# predict: B ground truth: A
# 空前后的词 [['a'], ['it']]
# 选项 [['coincidence'], ['change'], ['pity'], ['pain']]
# ---------20---------
# predict: A ground truth: B
# 空前后的词 [['there'], ['to']]
# 选项 [['on', 'board'], ['in', 'time'], ['for', 'sure'], ['on', 'purpose']]
# ---------1---------
# predict: A ground truth: C
# 空前后的词 [['i'], ['that']]
# 选项 [['knew'], ['understood'], ['noticed'], ['recognized']]
# ---------2---------
# predict: D ground truth: D
# 空前后的词 [['<s>'], ['he']]
# 选项 [['since'], ['even', 'if'], ['though'], ['as', 'if']]
# ---------3---------
# predict: D ground truth: B
# 空前后的词 [['newspaper'], ['in']]
# 选项 [['flat'], ['open'], ['cut'], ['fixed']]
# ---------4---------
# predict: A ground truth: C
# 空前后的词 [['was'], ['to']]
# 选项 [['hoping'], ['thinking'], ['pretending'], ['continuing']]
# ---------5---------
# predict: A ground truth: A
# 空前后的词 [['could'], ['that']]
# 选项 [['see'], ['find'], ['guess'], ['learn']]
# ---------6---------
# predict: C ground truth: D
# 空前后的词 [['my'], ['the']]
# 选项 [['menu'], ['bill'], ['paper'], ['food']]
# ---------7---------
# predict: D ground truth: B
# 空前后的词 [['the'], ['way']]
# 选项 [['direct'], ['familiar'], ['strange'], ['funny']]
# ---------8---------
# predict: B ground truth: A
# 空前后的词 [['i'], ['each']]
# 选项 [['chatted', 'with'], ['looked', 'at'], ['laughed', 'at'], ['talked', 'about']]
# ---------9---------
# predict: C ground truth: B
# 空前后的词 [['as'], ['went']]
# 选项 [['the', 'waiter'], ['time'], ['i'], ['the', 'dinner']]
# ---------10---------
# predict: C ground truth: C
# 空前后的词 [['became'], ['that']]
# 选项 [['true'], ['hopeful'], ['clear'], ['possible']]
# ---------11---------
# predict: D ground truth: D
# 空前后的词 [['the'], ['<s>']]
# 选项 [['restaurant'], ['washroom'], ['office'], ['kitchen']]
# ---------12---------
# predict: A ground truth: A
# 空前后的词 [['and'], ['without']]
# 选项 [['left'], ['acted'], ['sat', 'down'], ['calmed', 'down']]
# ---------13---------
# predict: A ground truth: A
# 空前后的词 [['had'], ['<s>']]
# 选项 [['wanted'], ['tried'], ['ordered'], ['wished']]
# ---------14---------
# predict: A ground truth: C
# 空前后的词 [['he'], ['you']]
# 选项 [['met'], ['caught'], ['followed'], ['discovered']]
# ---------15---------
# predict: A ground truth: D
# 空前后的词 [['he'], ['<s>']]
# 选项 [['was', 'to', 'beat'], ['was', 'dealing', 'with'], ['was', 'to', 'meet'], ['was', 'looking', 'for']]
# ---------16---------
# predict: B ground truth: B
# 空前后的词 [['my'], ['<s>']]
# 选项 [['care'], ['surprise'], ['worry'], ['regret']]
# ---------17---------
# predict: B ground truth: A
# 空前后的词 [['i'], ['say']]
# 选项 [['must'], ['can'], ['need'], ['may']]
# ---------18---------
# predict: B ground truth: B
# 空前后的词 [['a'], ['<s>']]
# 选项 [['discovery'], ['mistake'], ['decision'], ['fortune']]
# ---------19---------
# predict: D ground truth: D
# 空前后的词 [['really'], ['i']]
# 选项 [['a', 'pity'], ['natural'], ['a', 'chance'], ['lucky']]
# ---------20---------
# predict: B ground truth: C
# 空前后的词 [['<s>'], ['<s>']]
# 选项 [['thus'], ['however'], ['otherwise'], ['therefore']]
# ---------1---------
# predict: A ground truth: B
# 空前后的词 [['i'], ['the']]
# 选项 [['put', 'forward'], ['jumped', 'at'], ['tried', 'out'], ['turned', 'down']]
# ---------2---------
# predict: D ground truth: C
# 空前后的词 [['to'], ['a']]
# 选项 [['waste'], ['earn'], ['save'], ['pay']]
# ---------3---------
# predict: D ground truth: A
# 空前后的词 [["weren't"], ['enough']]
# 选项 [['excited'], ['worried'], ['moved'], ['tired']]
# ---------4---------
# predict: A ground truth: D
# 空前后的词 [['our'], ['was']]
# 选项 [['title'], ['competitor'], ['textbook'], ['instructor']]
# ---------5---------
# predict: D ground truth: D
# 空前后的词 [['which'], ['i']]
# 选项 [['urged'], ['demanded'], ['held'], ['meant']]
# ---------6---------
# predict: C ground truth: C
# 空前后的词 [["game's"], ['<s>']]
# 选项 [['fastest'], ['easiest'], ['best'], ['rarest']]
# ---------7---------
# predict: B ground truth: B
# 空前后的词 [['to'], ['him']]
# 选项 [['interview'], ['meet'], ['challenge'], ['beat']]
# ---------8---------
# predict: D ground truth: D
# 空前后的词 [['this'], ['was']]
# 选项 [['chance'], ['qualification'], ['honor'], ['job']]
# ---------9---------
# predict: D ground truth: C
# 空前后的词 [['it'], ['that']]
# 选项 [['real'], ['perfect'], ['clear'], ['possible']]
# ---------10---------
# predict: B ground truth: B
# 空前后的词 [['to'], ['the']]
# 选项 [['attend'], ['pass'], ['skip'], ['observe']]
# ---------11---------
# predict: C ground truth: C
# 空前后的词 [['to'], ['what']]
# 选项 [['add'], ['expose'], ['apply'], ['compare']]
# ---------12---------
# predict: B ground truth: A
# 空前后的词 [['<s>'], ['<s>']]
# 选项 [['eventually'], ['naturally'], ['directly'], ['normally']]
# ---------13---------
# predict: A ground truth: C
# 空前后的词 [['that'], ['and']]
# 选项 [['game'], ['presentation'], ['course'], ['experiment']]
# ---------14---------
# predict: B ground truth: B
# 空前后的词 [['the'], ['<s>']]
# 选项 [['criterion'], ['classroom'], ['department'], ['situation']]
# ---------15---------
# predict: A ground truth: A
# 空前后的词 [['he'], ['me']]
# 选项 [['taught'], ['wrote'], ['questioned'], ['promised']]
# ---------16---------
# predict: A ground truth: D
# 空前后的词 [['important'], ['that']]
# 选项 [['fact'], ['step'], ['manner'], ['skill']]
# ---------17---------
# predict: A ground truth: B
# 空前后的词 [['good'], ['<s>']]
# 选项 [['grades'], ['decisions'], ['impressions'], ['comments']]
# ---------18---------
# predict: B ground truth: A
# 空前后的词 [['to'], ['a']]
# 选项 [['analyze'], ['describe'], ['rebuild'], ['control']]
# ---------19---------
# predict: D ground truth: D
# 空前后的词 [['and'], ['the']]
# 选项 [['announce'], ['signal'], ['block'], ['evaluate']]
# ---------20---------
# predict: A ground truth: A
# 空前后的词 [['my'], ['as']]
# 选项 [['role'], ['desire'], ['concern'], ['behavior']]
# accuracy: 0.38333333333333336

# %%
test(content_list,options_list,answers_list,2,showAll=False)
# Out:
# ---------2---------
# predict: A ground truth: A
# 空前后的词 [['my'], ['when']]
# 选项 [['delight'], ['relief'], ['anger'], ['worry']]
# ---------10---------
# predict: D ground truth: D
# 空前后的词 [['was'], ['violently']]
# 选项 [['arguing'], ['fighting'], ['shouting'], ['shaking']]
# ---------14---------
# predict: D ground truth: D
# 空前后的词 [['i'], ['<s>']]
# 选项 [['agreed'], ['hesitated'], ['doubted'], ['knew']]
# ---------18---------
# predict: C ground truth: C
# 空前后的词 [['you'], ['my']]
# 选项 [['created'], ['honored'], ['saved'], ['guided']]
# ---------2---------
# predict: D ground truth: D
# 空前后的词 [['<s>'], ['he']]
# 选项 [['since'], ['even', 'if'], ['though'], ['as', 'if']]
# ---------5---------
# predict: A ground truth: A
# 空前后的词 [['could'], ['that']]
# 选项 [['see'], ['find'], ['guess'], ['learn']]
# ---------10---------
# predict: C ground truth: C
# 空前后的词 [['became'], ['that']]
# 选项 [['true'], ['hopeful'], ['clear'], ['possible']]
# ---------11---------
# predict: D ground truth: D
# 空前后的词 [['the'], ['<s>']]
# 选项 [['restaurant'], ['washroom'], ['office'], ['kitchen']]
# ---------12---------
# predict: A ground truth: A
# 空前后的词 [['and'], ['without']]
# 选项 [['left'], ['acted'], ['sat', 'down'], ['calmed', 'down']]
# ---------13---------
# predict: A ground truth: A
# 空前后的词 [['had'], ['<s>']]
# 选项 [['wanted'], ['tried'], ['ordered'], ['wished']]
# ---------16---------
# predict: B ground truth: B
# 空前后的词 [['my'], ['<s>']]
# 选项 [['care'], ['surprise'], ['worry'], ['regret']]
# ---------18---------
# predict: B ground truth: B
# 空前后的词 [['a'], ['<s>']]
# 选项 [['discovery'], ['mistake'], ['decision'], ['fortune']]
# ---------19---------
# predict: D ground truth: D
# 空前后的词 [['really'], ['i']]
# 选项 [['a', 'pity'], ['natural'], ['a', 'chance'], ['lucky']]
# ---------5---------
# predict: D ground truth: D
# 空前后的词 [['which'], ['i']]
# 选项 [['urged'], ['demanded'], ['held'], ['meant']]
# ---------6---------
# predict: C ground truth: C
# 空前后的词 [["game's"], ['<s>']]
# 选项 [['fastest'], ['easiest'], ['best'], ['rarest']]
# ---------7---------
# predict: B ground truth: B
# 空前后的词 [['to'], ['him']]
# 选项 [['interview'], ['meet'], ['challenge'], ['beat']]
# ---------8---------
# predict: D ground truth: D
# 空前后的词 [['this'], ['was']]
# 选项 [['chance'], ['qualification'], ['honor'], ['job']]
# ---------10---------
# predict: B ground truth: B
# 空前后的词 [['to'], ['the']]
# 选项 [['attend'], ['pass'], ['skip'], ['observe']]
# ---------11---------
# predict: C ground truth: C
# 空前后的词 [['to'], ['what']]
# 选项 [['add'], ['expose'], ['apply'], ['compare']]
# ---------14---------
# predict: B ground truth: B
# 空前后的词 [['the'], ['<s>']]
# 选项 [['criterion'], ['classroom'], ['department'], ['situation']]
# ---------15---------
# predict: A ground truth: A
# 空前后的词 [['he'], ['me']]
# 选项 [['taught'], ['wrote'], ['questioned'], ['promised']]
# ---------19---------
# predict: D ground truth: D
# 空前后的词 [['and'], ['the']]
# 选项 [['announce'], ['signal'], ['block'], ['evaluate']]
# ---------20---------
# predict: A ground truth: A
# 空前后的词 [['my'], ['as']]
# 选项 [['role'], ['desire'], ['concern'], ['behavior']]
# accuracy: 0.38333333333333336

# %% [markdown]
# <font color=blue size=15 face=雅黑>trigram Test</font>

# %%
N = 3
pre_words,be_words,words = count_word_num(lines,N)

# %%
content_list,options_list,answers_list = read_train_data(N)

# %%
test(content_list,options_list,answers_list,N,showAll=True)
# Out:
# ---------1---------
# predict: A ground truth: D
# 空前后的词 [['since', "i'd"], ['seen', 'him']]
# 选项 [['also'], ['often'], ['even'], ['last']]
# ---------2---------
# predict: A ground truth: A
# 空前后的词 [['imagine', 'my'], ['when', 'he']]
# 选项 [['delight'], ['relief'], ['anger'], ['worry']]
# ---------3---------
# predict: B ground truth: C
# 空前后的词 [['i', 'was'], ['<s>', '<s>']]
# 选项 [['scared'], ['shocked'], ['thrilled'], ['ashamed']]
# ---------4---------
# predict: C ground truth: C
# 空前后的词 [['supposed', 'to'], ['<s>', '<s>']]
# 选项 [['talk'], ['stay'], ['meet'], ['settle']]
# ---------5---------
# predict: A ground truth: A
# 空前后的词 [['bay', 'was'], ['in', 'sunshine']]
# 选项 [['bathed'], ['clean'], ['deep'], ['formed']]
# ---------6---------
# predict: C ground truth: B
# 空前后的词 [['a', 'little'], ['<s>', '<s>']]
# 选项 [['faster'], ['closer'], ['heavier'], ['wiser']]
# ---------7---------
# predict: A ground truth: A
# 空前后的词 [['was', 'in'], ['<s>', '<s>']]
# 选项 [['trouble'], ['advance'], ['question'], ['battle']]
# ---------8---------
# predict: C ground truth: B
# 空前后的词 [["something's", 'not'], ['<s>', '<s>']]
# 选项 [['real'], ['right'], ['fair'], ['fit']]
# ---------9---------
# predict: C ground truth: C
# 空前后的词 [['t-shirt', 'and'], ['into', 'the']]
# 选项 [['stared'], ['sank'], ['dived'], ['fell']]
# ---------10---------
# predict: D ground truth: D
# 空前后的词 [['he', 'was'], ['violently', '<s>']]
# 选项 [['arguing'], ['fighting'], ['shouting'], ['shaking']]
# ---------11---------
# predict: D ground truth: C
# 空前后的词 [['i', 'helped'], ['the', 'young']]
# 选项 [['lead'], ['persuade'], ['carry'], ['keep']]
# ---------12---------
# predict: A ground truth: B
# 空前后的词 [['<s>', 'something'], ['to', 'me']]
# 选项 [['happened'], ['occurred'], ['applied'], ['appealed']]
# ---------13---------
# predict: D ground truth: D
# 空前后的词 [['were', 'very'], ['<s>', '<s>']]
# 选项 [['sharp'], ['pleasant'], ['attractive'], ['familiar']]
# ---------14---------
# predict: B ground truth: D
# 空前后的词 [['immediately', 'i'], ['<s>', '<s>']]
# 选项 [['agreed'], ['hesitated'], ['doubted'], ['knew']]
# ---------15---------
# predict: A ground truth: A
# 空前后的词 [['<s>', '<s>'], ['<s>', '<s>']]
# 选项 [['fortunately'], ['frankly'], ['sadly'], ['suddenly']]
# ---------16---------
# predict: D ground truth: D
# 空前后的词 [['allowed', 'to'], ['and', 'later']]
# 选项 [['return'], ['relax'], ['speak'], ['leave']]
# ---------17---------
# predict: B ground truth: B
# 空前后的词 [['then', 'ben'], ['to', 'me']]
# 选项 [['joked'], ['turned'], ['listened'], ['pointed']]
# ---------18---------
# predict: C ground truth: C
# 空前后的词 [['<s>', 'you'], ['my', 'life']]
# 选项 [['created'], ['honored'], ['saved'], ['guided']]
# ---------19---------
# predict: C ground truth: A
# 空前后的词 [['what', 'a'], ['it', 'was']]
# 选项 [['coincidence'], ['change'], ['pity'], ['pain']]
# ---------20---------
# predict: B ground truth: B
# 空前后的词 [['was', 'there'], ['to', 'help']]
# 选项 [['on', 'board'], ['in', 'time'], ['for', 'sure'], ['on', 'purpose']]
# ---------1---------
# predict: B ground truth: C
# 空前后的词 [['suddenly', 'i'], ['that', 'a']]
# 选项 [['knew'], ['understood'], ['noticed'], ['recognized']]
# ---------2---------
# predict: D ground truth: D
# 空前后的词 [['<s>', '<s>'], ['he', 'knew']]
# 选项 [['since'], ['even', 'if'], ['though'], ['as', 'if']]
# ---------3---------
# predict: A ground truth: B
# 空前后的词 [['a', 'newspaper'], ['in', 'front']]
# 选项 [['flat'], ['open'], ['cut'], ['fixed']]
# ---------4---------
# predict: C ground truth: C
# 空前后的词 [['he', 'was'], ['to', 'read']]
# 选项 [['hoping'], ['thinking'], ['pretending'], ['continuing']]
# ---------5---------
# predict: A ground truth: A
# 空前后的词 [['i', 'could'], ['that', 'he']]
# 选项 [['see'], ['find'], ['guess'], ['learn']]
# ---------6---------
# predict: B ground truth: D
# 空前后的词 [['brought', 'my'], ['the', 'man']]
# 选项 [['menu'], ['bill'], ['paper'], ['food']]
# ---------7---------
# predict: C ground truth: B
# 空前后的词 [['by', 'the'], ['way', 'in']]
# 选项 [['direct'], ['familiar'], ['strange'], ['funny']]
# ---------8---------
# predict: B ground truth: A
# 空前后的词 [['and', 'i'], ['each', 'other']]
# 选项 [['chatted', 'with'], ['looked', 'at'], ['laughed', 'at'], ['talked', 'about']]
# ---------9---------
# predict: B ground truth: B
# 空前后的词 [['puzzled', 'as'], ['went', 'on']]
# 选项 [['the', 'waiter'], ['time'], ['i'], ['the', 'dinner']]
# ---------10---------
# predict: C ground truth: C
# 空前后的词 [['it', 'became'], ['that', 'all']]
# 选项 [['true'], ['hopeful'], ['clear'], ['possible']]
# ---------11---------
# predict: D ground truth: D
# 空前后的词 [['into', 'the'], ['<s>', '<s>']]
# 选项 [['restaurant'], ['washroom'], ['office'], ['kitchen']]
# ---------12---------
# predict: A ground truth: A
# 空前后的词 [['bill', 'and'], ['without', 'another']]
# 选项 [['left'], ['acted'], ['sat', 'down'], ['calmed', 'down']]
# ---------13---------
# predict: A ground truth: A
# 空前后的词 [['man', 'had'], ['<s>', '<s>']]
# 选项 [['wanted'], ['tried'], ['ordered'], ['wished']]
# ---------14---------
# predict: A ground truth: C
# 空前后的词 [['<s>', 'he'], ['you', 'here']]
# 选项 [['met'], ['caught'], ['followed'], ['discovered']]
# ---------15---------
# predict: A ground truth: D
# 空前后的词 [['man', 'he'], ['<s>', '<s>']]
# 选项 [['was', 'to', 'beat'], ['was', 'dealing', 'with'], ['was', 'to', 'meet'], ['was', 'looking', 'for']]
# ---------16---------
# predict: A ground truth: B
# 空前后的词 [['showing', 'my'], ['<s>', '<s>']]
# 选项 [['care'], ['surprise'], ['worry'], ['regret']]
# ---------17---------
# predict: B ground truth: A
# 空前后的词 [['<s>', 'i'], ['say', 'he']]
# 选项 [['must'], ['can'], ['need'], ['may']]
# ---------18---------
# predict: B ground truth: B
# 空前后的词 [['made', 'a'], ['<s>', '<s>']]
# 选项 [['discovery'], ['mistake'], ['decision'], ['fortune']]
# ---------19---------
# predict: A ground truth: D
# 空前后的词 [["it's", 'really'], ['i', 'came']]
# 选项 [['a', 'pity'], ['natural'], ['a', 'chance'], ['lucky']]
# ---------20---------
# predict: B ground truth: C
# 空前后的词 [['<s>', '<s>'], ['<s>', '<s>']]
# 选项 [['thus'], ['however'], ['otherwise'], ['therefore']]
# ---------1---------
# predict: A ground truth: B
# 空前后的词 [['<s>', 'i'], ['the', 'idea']]
# 选项 [['put', 'forward'], ['jumped', 'at'], ['tried', 'out'], ['turned', 'down']]
# ---------2---------
# predict: C ground truth: C
# 空前后的词 [['want', 'to'], ['a', 'few']]
# 选项 [['waste'], ['earn'], ['save'], ['pay']]
# ---------3---------
# predict: A ground truth: A
# 空前后的词 [['i', "weren't"], ['enough', 'about']]
# 选项 [['excited'], ['worried'], ['moved'], ['tired']]
# ---------4---------
# predict: A ground truth: D
# 空前后的词 [['about', 'our'], ['was', 'appealing']]
# 选项 [['title'], ['competitor'], ['textbook'], ['instructor']]
# ---------5---------
# predict: D ground truth: D
# 空前后的词 [['<s>', 'which'], ['i', 'would']]
# 选项 [['urged'], ['demanded'], ['held'], ['meant']]
# ---------6---------
# predict: A ground truth: C
# 空前后的词 [['the', "game's"], ['<s>', '<s>']]
# 选项 [['fastest'], ['easiest'], ['best'], ['rarest']]
# ---------7---------
# predict: B ground truth: B
# 空前后的词 [['wait', 'to'], ['him', '<s>']]
# 选项 [['interview'], ['meet'], ['challenge'], ['beat']]
# ---------8---------
# predict: D ground truth: D
# 空前后的词 [['and', 'this'], ['was', 'no']]
# 选项 [['chance'], ['qualification'], ['honor'], ['job']]
# ---------9---------
# predict: C ground truth: C
# 空前后的词 [['made', 'it'], ['that', 'our']]
# 选项 [['real'], ['perfect'], ['clear'], ['possible']]
# ---------10---------
# predict: A ground truth: B
# 空前后的词 [['order', 'to'], ['the', 'class']]
# 选项 [['attend'], ['pass'], ['skip'], ['observe']]
# ---------11---------
# predict: D ground truth: C
# 空前后的词 [['plan', 'to'], ['what', 'we']]
# 选项 [['add'], ['expose'], ['apply'], ['compare']]
# ---------12---------
# predict: A ground truth: A
# 空前后的词 [['<s>', '<s>'], ['<s>', '<s>']]
# 选项 [['eventually'], ['naturally'], ['directly'], ['normally']]
# ---------13---------
# predict: C ground truth: C
# 空前后的词 [['in', 'that'], ['and', 'learned']]
# 选项 [['game'], ['presentation'], ['course'], ['experiment']]
# ---------14---------
# predict: B ground truth: B
# 空前后的词 [['beyond', 'the'], ['<s>', '<s>']]
# 选项 [['criterion'], ['classroom'], ['department'], ['situation']]
# ---------15---------
# predict: A ground truth: A
# 空前后的词 [['what', 'he'], ['me', ':the']]
# 选项 [['taught'], ['wrote'], ['questioned'], ['promised']]
# ---------16---------
# predict: D ground truth: D
# 空前后的词 [['most', 'important'], ['that', 'you']]
# 选项 [['fact'], ['step'], ['manner'], ['skill']]
# ---------17---------
# predict: B ground truth: B
# 空前后的词 [['make', 'good'], ['<s>', '<s>']]
# 选项 [['grades'], ['decisions'], ['impressions'], ['comments']]
# ---------18---------
# predict: B ground truth: A
# 空前后的词 [['have', 'to'], ['a', 'situation']]
# 选项 [['analyze'], ['describe'], ['rebuild'], ['control']]
# ---------19---------
# predict: C ground truth: D
# 空前后的词 [['doing', 'and'], ['the', 'best']]
# 选项 [['announce'], ['signal'], ['block'], ['evaluate']]
# ---------20---------
# predict: A ground truth: A
# 空前后的词 [['in', 'my'], ['as', 'a']]
# 选项 [['role'], ['desire'], ['concern'], ['behavior']]
# accuracy: 0.5666666666666667

# %%
test(content_list,options_list,answers_list,N,showAll=False)
# Out:
# ---------2---------
# predict: A ground truth: A
# 空前后的词 [['imagine', 'my'], ['when', 'he']]
# 选项 [['delight'], ['relief'], ['anger'], ['worry']]
# ---------4---------
# predict: C ground truth: C
# 空前后的词 [['supposed', 'to'], ['<s>', '<s>']]
# 选项 [['talk'], ['stay'], ['meet'], ['settle']]
# ---------5---------
# predict: A ground truth: A
# 空前后的词 [['bay', 'was'], ['in', 'sunshine']]
# 选项 [['bathed'], ['clean'], ['deep'], ['formed']]
# ---------7---------
# predict: A ground truth: A
# 空前后的词 [['was', 'in'], ['<s>', '<s>']]
# 选项 [['trouble'], ['advance'], ['question'], ['battle']]
# ---------9---------
# predict: C ground truth: C
# 空前后的词 [['t-shirt', 'and'], ['into', 'the']]
# 选项 [['stared'], ['sank'], ['dived'], ['fell']]
# ---------10---------
# predict: D ground truth: D
# 空前后的词 [['he', 'was'], ['violently', '<s>']]
# 选项 [['arguing'], ['fighting'], ['shouting'], ['shaking']]
# ---------13---------
# predict: D ground truth: D
# 空前后的词 [['were', 'very'], ['<s>', '<s>']]
# 选项 [['sharp'], ['pleasant'], ['attractive'], ['familiar']]
# ---------15---------
# predict: A ground truth: A
# 空前后的词 [['<s>', '<s>'], ['<s>', '<s>']]
# 选项 [['fortunately'], ['frankly'], ['sadly'], ['suddenly']]
# ---------16---------
# predict: D ground truth: D
# 空前后的词 [['allowed', 'to'], ['and', 'later']]
# 选项 [['return'], ['relax'], ['speak'], ['leave']]
# ---------17---------
# predict: B ground truth: B
# 空前后的词 [['then', 'ben'], ['to', 'me']]
# 选项 [['joked'], ['turned'], ['listened'], ['pointed']]
# ---------18---------
# predict: C ground truth: C
# 空前后的词 [['<s>', 'you'], ['my', 'life']]
# 选项 [['created'], ['honored'], ['saved'], ['guided']]
# ---------20---------
# predict: B ground truth: B
# 空前后的词 [['was', 'there'], ['to', 'help']]
# 选项 [['on', 'board'], ['in', 'time'], ['for', 'sure'], ['on', 'purpose']]
# ---------2---------
# predict: D ground truth: D
# 空前后的词 [['<s>', '<s>'], ['he', 'knew']]
# 选项 [['since'], ['even', 'if'], ['though'], ['as', 'if']]
# ---------4---------
# predict: C ground truth: C
# 空前后的词 [['he', 'was'], ['to', 'read']]
# 选项 [['hoping'], ['thinking'], ['pretending'], ['continuing']]
# ---------5---------
# predict: A ground truth: A
# 空前后的词 [['i', 'could'], ['that', 'he']]
# 选项 [['see'], ['find'], ['guess'], ['learn']]
# ---------9---------
# predict: B ground truth: B
# 空前后的词 [['puzzled', 'as'], ['went', 'on']]
# 选项 [['the', 'waiter'], ['time'], ['i'], ['the', 'dinner']]
# ---------10---------
# predict: C ground truth: C
# 空前后的词 [['it', 'became'], ['that', 'all']]
# 选项 [['true'], ['hopeful'], ['clear'], ['possible']]
# ---------11---------
# predict: D ground truth: D
# 空前后的词 [['into', 'the'], ['<s>', '<s>']]
# 选项 [['restaurant'], ['washroom'], ['office'], ['kitchen']]
# ---------12---------
# predict: A ground truth: A
# 空前后的词 [['bill', 'and'], ['without', 'another']]
# 选项 [['left'], ['acted'], ['sat', 'down'], ['calmed', 'down']]
# ---------13---------
# predict: A ground truth: A
# 空前后的词 [['man', 'had'], ['<s>', '<s>']]
# 选项 [['wanted'], ['tried'], ['ordered'], ['wished']]
# ---------18---------
# predict: B ground truth: B
# 空前后的词 [['made', 'a'], ['<s>', '<s>']]
# 选项 [['discovery'], ['mistake'], ['decision'], ['fortune']]
# ---------2---------
# predict: C ground truth: C
# 空前后的词 [['want', 'to'], ['a', 'few']]
# 选项 [['waste'], ['earn'], ['save'], ['pay']]
# ---------3---------
# predict: A ground truth: A
# 空前后的词 [['i', "weren't"], ['enough', 'about']]
# 选项 [['excited'], ['worried'], ['moved'], ['tired']]
# ---------5---------
# predict: D ground truth: D
# 空前后的词 [['<s>', 'which'], ['i', 'would']]
# 选项 [['urged'], ['demanded'], ['held'], ['meant']]
# ---------7---------
# predict: B ground truth: B
# 空前后的词 [['wait', 'to'], ['him', '<s>']]
# 选项 [['interview'], ['meet'], ['challenge'], ['beat']]
# ---------8---------
# predict: D ground truth: D
# 空前后的词 [['and', 'this'], ['was', 'no']]
# 选项 [['chance'], ['qualification'], ['honor'], ['job']]
# ---------9---------
# predict: C ground truth: C
# 空前后的词 [['made', 'it'], ['that', 'our']]
# 选项 [['real'], ['perfect'], ['clear'], ['possible']]
# ---------12---------
# predict: A ground truth: A
# 空前后的词 [['<s>', '<s>'], ['<s>', '<s>']]
# 选项 [['eventually'], ['naturally'], ['directly'], ['normally']]
# ---------13---------
# predict: C ground truth: C
# 空前后的词 [['in', 'that'], ['and', 'learned']]
# 选项 [['game'], ['presentation'], ['course'], ['experiment']]
# ---------14---------
# predict: B ground truth: B
# 空前后的词 [['beyond', 'the'], ['<s>', '<s>']]
# 选项 [['criterion'], ['classroom'], ['department'], ['situation']]
# ---------15---------
# predict: A ground truth: A
# 空前后的词 [['what', 'he'], ['me', ':the']]
# 选项 [['taught'], ['wrote'], ['questioned'], ['promised']]
# ---------16---------
# predict: D ground truth: D
# 空前后的词 [['most', 'important'], ['that', 'you']]
# 选项 [['fact'], ['step'], ['manner'], ['skill']]
# ---------17---------
# predict: B ground truth: B
# 空前后的词 [['make', 'good'], ['<s>', '<s>']]
# 选项 [['grades'], ['decisions'], ['impressions'], ['comments']]
# ---------20---------
# predict: A ground truth: A
# 空前后的词 [['in', 'my'], ['as', 'a']]
# 选项 [['role'], ['desire'], ['concern'], ['behavior']]
# accuracy: 0.5666666666666667

# %%
tt = 'has a'
print(pre_words[tt])
# Out:
# 1865

# %%
n = len(tt)
for key, value in words.items():
#     print(key[:n])
    if key[:n] == tt and key[n]==' ':
        print(key,' : ',value)
# Out:
# has a special  :  39
# has a small  :  22
# has a gun  :  2
# has a serious  :  8
# has a psychological  :  1
# has a planner  :  1
# has a long  :  47
# has a winner  :  1
# has a lower  :  2
# has a wall  :  1
# has a very  :  58
# has a destination  :  2
# has a smart  :  1
# has a master's  :  1
# has a growing  :  6
# has a real  :  4
# has a chronic  :  1
# has a final  :  1
# has a statue  :  4
# has a beautiful  :  8
# has a bathroom  :  1
# has a spiritual  :  1
# has a great  :  45
# has a team  :  5
# has a roof  :  1
# has a major  :  5
# has a joyful  :  1
# has a successful  :  1
# has a planned  :  2
# has a calculator  :  1
# has a normal  :  3
# has a population  :  18
# has a free  :  4
# has a lot  :  96
# has a strong  :  14
# has a right  :  3
# has a structure  :  1
# has a bulletproof  :  1
# has a cause  :  2
# has a movie  :  3
# has a large  :  30
# has a land  :  1
# has a nice  :  9
# has a sleep  :  1
# has a greater  :  7
# has a set  :  3
# has a concussion  :  1
# has a girlfriend  :  2
# has a problem  :  11
# has a younger  :  1
# has a decade's  :  1
# has a waiting  :  2
# has a child  :  2
# has a unique  :  11
# has a one-in-10  :  1
# has a business  :  1
# has a certain  :  9
# has a touch  :  2
# has a sudden  :  2
# has a drink  :  1
# has a chain  :  2
# has a computer  :  10
# has a chance  :  5
# has a high  :  7
# has a design  :  1
# has a website  :  7
# has a battery  :  1
# has a new  :  21
# has a waste  :  3
# has a recycling  :  3
# has a variety  :  5
# has a good  :  60
# has a color  :  2
# has a strategic  :  1
# has a ly  :  1
# has a husband  :  1
# has a whistle  :  1
# has a daughter  :  6
# has a 100  :  3
# has a system  :  1
# has a life  :  2
# has a built-in  :  8
# has a protective  :  2
# has a solution  :  3
# has a program  :  3
# has a livestock  :  1
# has a motivating  :  1
# has a scanner  :  1
# has a different  :  26
# has a baby  :  5
# has a view  :  2
# has a device  :  1
# has a natural  :  7
# has a talent  :  2
# has a total  :  4
# has a wingspread  :  2
# has a disagreeable  :  1
# has a better  :  10
# has a reason  :  1
# has a front  :  2
# has a lawn  :  1
# has a private  :  4
# has a runway  :  1
# has a rare  :  3
# has a library  :  3
# has a direct  :  8
# has a place  :  5
# has a limited  :  4
# has a huge  :  14
# has a tattoo  :  4
# has a vast  :  2
# has a way  :  13
# has a tape  :  2
# has a history  :  13
# has a lively  :  6
# has a terminal  :  1
# has a depressed  :  1
# has a post  :  1
# has a smiling  :  2
# has a period  :  1
# has a splendid  :  1
# has a negative  :  6
# has a big  :  37
# has a hard  :  5
# has a consistent  :  1
# has a duty  :  4
# has a range  :  2
# has a choice  :  1
# has a price  :  4
# has a scholarship  :  1
# has a drop  :  1
# has a short  :  4
# has a healthy  :  2
# has a hindu  :  1
# has a commitment  :  1
# has a deep  :  3
# has a republican  :  1
# has a number  :  15
# has a recharge  :  1
# has a full-time  :  2
# has a familiar  :  1
# has a smaller  :  2
# has a learning  :  2
# has a contagious  :  1
# has a two-storey  :  3
# has a tangible  :  1
# has a wide  :  8
# has a hole  :  2
# has a phone  :  2
# has a comfortable  :  2
# has a statement  :  1
# has a challenge  :  2
# has a rhyme  :  1
# has a meal  :  3
# has a simple  :  2
# has a positive  :  5
# has a deal  :  2
# has a two-year-old  :  1
# has a law  :  1
# has a truly  :  1
# has a farm  :  1
# has a dynamic  :  1
# has a pleasant  :  6
# has a past  :  2
# has a microphone  :  1
# has a common  :  1
# has a pure  :  1
# has a continuing  :  1
# has a hotel  :  6
# has a port  :  2
# has a little  :  9
# has a leg  :  1
# has a single  :  3
# has a kind  :  1
# has a non-functioning  :  1
# has a green  :  3
# has a completely  :  3
# has a poor  :  8
# has a pet  :  4
# has a strict  :  2
# has a typical  :  1
# has a lie-in  :  2
# has a starring  :  2
# has a higher  :  7
# has a rich  :  9
# has a sick  :  6
# has a joke  :  1
# has a bigger  :  4
# has a similar  :  9
# has a few  :  8
# has a double  :  1
# has a book  :  2
# has a storymarlisa  :  1
# has a perigee  :  1
# has a daily  :  3
# has a gunit  :  1
# has a value  :  4
# has a national  :  2
# has a television  :  5
# has a heart  :  3
# has a warm  :  2
# has a really  :  2
# has a laptop  :  3
# has a heated  :  1
# has a powerful  :  6
# has a clever  :  1
# has a lid  :  1
# has a slow  :  1
# has a well-respected  :  1
# has a fine  :  3
# has a particular  :  4
# has a larger  :  1
# has a wonderful  :  5
# has a more  :  6
# has a growth  :  1
# has a touch-panel  :  1
# has a milder  :  1
# has a tall  :  1
# has a just  :  3
# has a diameter  :  2
# has a micro-  :  1
# has a mix  :  1
# has a lounge  :  1
# has a mass  :  2
# has a summerhouse  :  1
# has a hump  :  1
# has a layer  :  1
# has a 'local'  :  1
# has a clean  :  1
# has a thorough  :  1
# has a listing  :  1
# has a quieter  :  1
# has a brilliant  :  1
# has a dining  :  1
# has a long-standing  :  1
# has a financial  :  1
# has a passionate  :  1
# has a less  :  1
# has a sad  :  1
# has a monkey  :  1
# has a year-round  :  1
# has a cottage  :  1
# has a license  :  1
# has a traffic  :  1
# has a list  :  4
# has a ready  :  1
# has a league  :  1
# has a car  :  10
# has a sharp  :  1
# has a generator  :  1
# has a friend  :  2
# has a word  :  1
# has a silicon  :  1
# has a problemthe  :  1
# has a clearly  :  1
# has a gift  :  3
# has a picture  :  4
# has a freshly-minted  :  1
# has a close  :  1
# has a couple  :  1
# has a group  :  2
# has a sister  :  8
# has a king  :  1
# has a deadly  :  1
# has a students'  :  1
# has a psychology  :  1
# has a dual  :  1
# has a detailed  :  1
# has a longstanding  :  1
# has a culture  :  1
# has a microchip  :  1
# has a carrier  :  1
# has a laboratory  :  1
# has a clock  :  1
# has a tropical  :  1
# has a string  :  1
# has a profession  :  1
# has a diary  :  1
# has a low  :  1
# has a doctor  :  4
# has a purpose  :  3
# has a netizen  :  1
# has a doubt  :  1
# has a collection  :  3
# has a diverse  :  1
# has a lens  :  1
# has a character  :  3
# has a significant  :  4
# has a 50  :  1
# has a recognized  :  1
# has a silver  :  3
# has a modern  :  1
# has a consulting  :  1
# has a versatile  :  1
# has a feeling  :  2
# has a dream  :  5
# has a database  :  2
# has a famous  :  2
# has a bright  :  4
# has a market  :  1
# has a stick  :  1
# has a bar  :  4
# has a downside  :  1
# has a distinctive  :  1
# has a prime  :  2
# has a reasonable  :  3
# has a 'gnh'which  :  1
# has a network  :  3
# has a cold  :  5
# has a fuel  :  1
# has a remarkable  :  2
# has a homeless  :  1
# has a fast  :  2
# has a language  :  1
# has a tv  :  2
# has a low-level  :  2
# has a code  :  1
# has a snow  :  1
# has a need  :  2
# has a saltwater  :  1
# has a phd  :  1
# has a story  :  7
# has a rule  :  3
# has a head  :  6
# has a look  :  4
# has a humanistic  :  1
# has a button  :  1
# has a record  :  1
# has a contemporary  :  1
# has a smile  :  2
# has a sensitive  :  2
# has a blood  :  1
# has a right-on  :  1
# has a dolphin  :  1
# has a wave  :  1
# has a hair-raising  :  1
# has a mountain  :  2
# has a beneficial  :  5
# has a bed  :  2
# has a wellrespected  :  1
# has a white  :  4
# has a though  :  1
# has a colored  :  1
# has a clutch  :  1
# has a wreck  :  1
# has a much  :  7
# has a wounded  :  1
# has a massive  :  1
# has a message  :  3
# has a memorable  :  1
# has a bad  :  13
# has a maximum  :  4
# has a voltage  :  2
# has a panel  :  1
# has a clear  :  3
# has a basic  :  1
# has a top--level  :  1
# has a target  :  1
# has a shorter  :  2
# has a legal  :  2
# has a faulty  :  1
# has a red  :  3
# has a 20  :  1
# has a mother  :  1
# has a fantastic  :  2
# has a name  :  9
# has a speaker  :  1
# has a host  :  2
# has a delightful  :  1
# has a devoted  :  1
# has a fierce  :  1
# has a home  :  5
# has a relaxing  :  1
# has a body  :  2
# has a biological  :  1
# has a televisionair  :  1
# has a piece  :  4
# has a disability  :  2
# has a 400-meter  :  1
# has a broader  :  1
# has a lasting  :  1
# has a forest  :  1
# has a country  :  2
# has a lovely  :  2
# has a dramatic  :  1
# has a sense  :  3
# has a dehydrating  :  1
# has a ripple  :  1
# has a birthday  :  3
# has a reputation  :  1
# has a nationally  :  1
# has a substantial  :  1
# has a noticeable  :  1
# has a thief  :  1
# has a magical  :  4
# has a tragic  :  1
# has a job  :  3
# has a nasty  :  1
# has a further  :  1
# has a playlist  :  1
# has a sweet  :  4
# has a series  :  1
# has a cucumber  :  1
# has a pear  :  1
# has a solid  :  2
# has a thrifty  :  1
# has a local  :  1
# has a coldis  :  1
# has a yellow  :  4
# has a compact  :  1
# has a virus  :  1
# has a non-contact  :  1
# has a catering  :  1
# has a longer  :  2
# has a depressing  :  1
# has a budget  :  1
# has a popular  :  2
# has a preference  :  1
# has a staff  :  1
# has a summer  :  1
# has a plan  :  4
# has a complete  :  1
# has a legitimate  :  1
# has a casual  :  2
# has a spirit  :  1
# has a carpet  :  1
# has a sauna  :  4
# has a rapidly  :  1
# has a humanlike  :  1
# has a resort  :  1
# has a set-point  :  1
# has a mobile  :  2
# has a grey  :  1
# has a government  :  1
# has a giant  :  1
# has a wingspan  :  1
# has a primary  :  1
# has a vision  :  2
# has a picnic  :  2
# has a membership  :  1
# has a humanoid  :  1
# has a family  :  5
# has a zoo  :  1
# has a manager  :  1
# has a happy  :  5
# has a gold  :  1
# has a smiley  :  1
# has a central  :  2
# has a point---foreigners  :  1
# has a passionbut  :  1
# has a style  :  1
# has a decimal  :  1
# has a stronger  :  1
# has a packed  :  1
# has a two-meter  :  1
# has a holiday  :  3
# has a planet  :  2
# has a universalist  :  1
# has a theory  :  1
# has a transparent  :  1
# has a key  :  1
# has a black  :  7
# has a flattering  :  1
# has a rhyming  :  1
# has a division  :  1
# has a motor  :  1
# has a statistical  :  1
# has a specific  :  1
# has a quicker  :  1
# has a hardwood  :  1
# has a passion  :  2
# has a comforting  :  1
# has a cradle  :  1
# has a personality  :  1
# has a magazine  :  1
# has a relationship  :  1
# has a driving  :  1
# has a mind  :  3
# has a practice  :  1
# has a building  :  1
# has a steering  :  1
# has a blood-red  :  1
# has a part  :  2
# has a 90  :  1
# has a bath  :  2
# has a tendency  :  2
# has a form  :  1
# has a kid  :  1
# has a medical  :  1
# has a track  :  1
# has a dog  :  6
# has a custom  :  1
# has a fascination  :  1
# has a boy's  :  1
# has a brain  :  1
# has a bird  :  2
# has a first  :  2
# has a voice  :  2
# has a meditation  :  1
# has a magic  :  1
# has a chinese-singaporean  :  1
# has a companion  :  1
# has a sidewalk  :  1
# has a coin  :  3
# has a cellphone  :  1
# has a boiling  :  1
# has a favorite  :  1
# has a well-planned  :  1
# has a historic  :  1
# has a swimming  :  3
# has a changing  :  1
# has a royal  :  1
# has a ling  :  1
# has a minor  :  1
# has a clearance  :  1
# has a brush  :  1
# has a question  :  3
# has a tooth  :  1
# has a school  :  1
# has a 24-jewel  :  1
# has a year  :  1
# has a stunt  :  1
# has a pop  :  1
# has a male  :  1
# has a blog  :  1
# has a cup  :  3
# has a steel  :  1
# has a theme  :  2
# has a sorry  :  1
# has a condition  :  1
# has a plant  :  1
# has a golf  :  1
# has a mental  :  2
# has a position  :  2
# has a disabled  :  1
# has a kids'  :  1
# has a degree  :  1
# has a latency  :  1
# has a tiny  :  1
# has a students'union  :  1
# has a rosy  :  1
# has a functional  :  1
# has a logical  :  1
# has a role  :  1
# has a vital  :  1
# has a running  :  1
# has a cost  :  1
# has a fold-down  :  1
# has a weight  :  1
# has a parachute  :  1
# has a strong-willed  :  1
# has a cancer  :  1
# has a distinct  :  1
# has a depressive  :  1
# has a disadvantage  :  1
# has a belief  :  1
# has a gene  :  1
# has a myth  :  1
# has a straight  :  1
# has a light-coloured  :  1
# has a responsibility  :  1
# has a loving  :  1
# has a project  :  1
# has a 24  :  1
# has a graduated  :  1
# has a paper  :  1
# has a shop  :  2
# has a present  :  1
# has a seat  :  1
# has a busy  :  1
# has a theatre  :  1
# has a panda  :  1
# has a dangerous  :  1
# has a brother  :  4
# has a beginning  :  1
# has a biology  :  1
# has a music  :  2
# has a p  :  1
# has a factory  :  2
# has a test  :  1
# has a headmaster  :  1
# has a pocket  :  1
# has a cat  :  2
# has a grade  :  1
# has a desk  :  2
# has a stepson  :  1
# has a four-year-old  :  3
# has a flag  :  1
# has a round  :  12
# has a pen  :  4
# has a children's  :  1
# has a type  :  3
# has a sign  :  2
# has a dictionary  :  2
# has a watch  :  1
# has a garden  :  3
# has a on  :  1
# has a sports  :  4
# has a boom  :  1
# has a hamburger  :  1
# has a terrible  :  3
# has a son  :  5
# has a drive's  :  1
# has a table  :  1
# has a dress  :  1
# has a lead  :  1
# has a hobby  :  2
# has a deadline  :  1
# has a meaning  :  3
# has a nervous  :  2
# has a pair  :  1
# has a colorful  :  1
# has a day  :  1
# has a colour  :  1
# has a map  :  4
# has a police  :  1
# has a from  :  2
# has a whole  :  2
# has a liver  :  1
# has a bike  :  1
# has a traveling  :  1
# has a blood-alcohol  :  2
# has a bucket  :  1
# has a clown  :  1
# has a closer  :  1
# has a partner  :  1
# has a meeting  :  1
# has a rest  :  1
# has a of  :  1
# has a chinese  :  2
# has a photo  :  1
# has a gasoline  :  1
# has a cd  :  1
# has a room  :  2
# has a show  :  1
# has a competition  :  1
# has a glass  :  2
# has a part-time  :  1
# has a season  :  1
# has a waterfall  :  1
# has a functioning  :  1
# has a toy  :  1
# has a cool  :  2
# has a christmas  :  1
# has a surface  :  1
# has a break  :  1
# has a volleyball  :  1
# has a too  :  1
# has a headachehe  :  1
# has a possible  :  1
# has a jacket  :  1
# has a foreign  :  1
# has a talk  :  1
# has a pug-dog  :  1
# has a dark  :  2
# has a historical  :  1
# has a baseball  :  1
# has a parrot  :  1
# has a hero  :  1
# has a genetic  :  1
# has a balcony  :  1
# has a non-touch  :  1
# has a face  :  1
# has a 2-year-younger  :  1
# has a speed  :  1
# has a label  :  1
# has a shower  :  1
# has a flay  :  1
# has a secret  :  1
# has a store  :  1
# has a bag  :  1
# has a cinema  :  1
# has a cousin  :  1

# %% [markdown]
# <font color=blue size=15 face=雅黑>fourgram Test</font>

# %%
N = 4
pre_words,be_words,words = count_word_num(lines,N)
content_list,options_list,answers_list = read_train_data(N)
test(content_list,options_list,answers_list,N,showAll=True)
# Out:
# ---------1---------
# predict: A ground truth: D
# 空前后的词 [['years', 'since', "i'd"], ['seen', 'him', '<s>']]
# 选项 [['also'], ['often'], ['even'], ['last']]
# ---------2---------
# predict: A ground truth: A
# 空前后的词 [['so', 'imagine', 'my'], ['when', 'he', 'emailed']]
# 选项 [['delight'], ['relief'], ['anger'], ['worry']]
# ---------3---------
# predict: B ground truth: C
# 空前后的词 [['<s>', 'i', 'was'], ['<s>', '<s>', '<s>']]
# 选项 [['scared'], ['shocked'], ['thrilled'], ['ashamed']]
# ---------4---------
# predict: A ground truth: C
# 空前后的词 [['were', 'supposed', 'to'], ['<s>', '<s>', '<s>']]
# 选项 [['talk'], ['stay'], ['meet'], ['settle']]
# ---------5---------
# predict: A ground truth: A
# 空前后的词 [['the', 'bay', 'was'], ['in', 'sunshine', '<s>']]
# 选项 [['bathed'], ['clean'], ['deep'], ['formed']]
# ---------6---------
# predict: C ground truth: B
# 空前后的词 [['getting', 'a', 'little'], ['<s>', '<s>', '<s>']]
# 选项 [['faster'], ['closer'], ['heavier'], ['wiser']]
# ---------7---------
# predict: A ground truth: A
# 空前后的词 [['kayak', 'was', 'in'], ['<s>', '<s>', '<s>']]
# 选项 [['trouble'], ['advance'], ['question'], ['battle']]
# ---------8---------
# predict: A ground truth: B
# 空前后的词 [['<s>', "something's", 'not'], ['<s>', '<s>', '<s>']]
# 选项 [['real'], ['right'], ['fair'], ['fit']]
# ---------9---------
# predict: B ground truth: C
# 空前后的词 [['my', 't-shirt', 'and'], ['into', 'the', 'water']]
# 选项 [['stared'], ['sank'], ['dived'], ['fell']]
# ---------10---------
# predict: D ground truth: D
# 空前后的词 [['<s>', 'he', 'was'], ['violently', '<s>', '<s>']]
# 选项 [['arguing'], ['fighting'], ['shouting'], ['shaking']]
# ---------11---------
# predict: B ground truth: C
# 空前后的词 [['instructors，', 'i', 'helped'], ['the', 'young', 'man']]
# 选项 [['lead'], ['persuade'], ['carry'], ['keep']]
# ---------12---------
# predict: A ground truth: B
# 空前后的词 [['<s>', '<s>', 'something'], ['to', 'me', '<s>']]
# 选项 [['happened'], ['occurred'], ['applied'], ['appealed']]
# ---------13---------
# predict: D ground truth: D
# 空前后的词 [['eyes', 'were', 'very'], ['<s>', '<s>', '<s>']]
# 选项 [['sharp'], ['pleasant'], ['attractive'], ['familiar']]
# ---------14---------
# predict: A ground truth: D
# 空前后的词 [['and', 'immediately', 'i'], ['<s>', '<s>', '<s>']]
# 选项 [['agreed'], ['hesitated'], ['doubted'], ['knew']]
# ---------15---------
# predict: A ground truth: A
# 空前后的词 [['<s>', '<s>', '<s>'], ['<s>', '<s>', '<s>']]
# 选项 [['fortunately'], ['frankly'], ['sadly'], ['suddenly']]
# ---------16---------
# predict: D ground truth: D
# 空前后的词 [['be', 'allowed', 'to'], ['and', 'later', 'the']]
# 选项 [['return'], ['relax'], ['speak'], ['leave']]
# ---------17---------
# predict: B ground truth: B
# 空前后的词 [['and', 'then', 'ben'], ['to', 'me', '<s>']]
# 选项 [['joked'], ['turned'], ['listened'], ['pointed']]
# ---------18---------
# predict: C ground truth: C
# 空前后的词 [['<s>', '<s>', 'you'], ['my', 'life', '<s>']]
# 选项 [['created'], ['honored'], ['saved'], ['guided']]
# ---------19---------
# predict: C ground truth: A
# 空前后的词 [['believe', 'what', 'a'], ['it', 'was', '<s>']]
# 选项 [['coincidence'], ['change'], ['pity'], ['pain']]
# ---------20---------
# predict: B ground truth: B
# 空前后的词 [['i', 'was', 'there'], ['to', 'help', 'my']]
# 选项 [['on', 'board'], ['in', 'time'], ['for', 'sure'], ['on', 'purpose']]
# ---------1---------
# predict: C ground truth: C
# 空前后的词 [['<s>', 'suddenly', 'i'], ['that', 'a', 'man']]
# 选项 [['knew'], ['understood'], ['noticed'], ['recognized']]
# ---------2---------
# predict: D ground truth: D
# 空前后的词 [['<s>', '<s>', '<s>'], ['he', 'knew', 'me']]
# 选项 [['since'], ['even', 'if'], ['though'], ['as', 'if']]
# ---------3---------
# predict: A ground truth: B
# 空前后的词 [['had', 'a', 'newspaper'], ['in', 'front', 'of']]
# 选项 [['flat'], ['open'], ['cut'], ['fixed']]
# ---------4---------
# predict: C ground truth: C
# 空前后的词 [['which', 'he', 'was'], ['to', 'read', '<s>']]
# 选项 [['hoping'], ['thinking'], ['pretending'], ['continuing']]
# ---------5---------
# predict: A ground truth: A
# 空前后的词 [['but', 'i', 'could'], ['that', 'he', 'was']]
# 选项 [['see'], ['find'], ['guess'], ['learn']]
# ---------6---------
# predict: A ground truth: D
# 空前后的词 [['waiter', 'brought', 'my'], ['the', 'man', 'was']]
# 选项 [['menu'], ['bill'], ['paper'], ['food']]
# ---------7---------
# predict: A ground truth: B
# 空前后的词 [['puzzled', 'by', 'the'], ['way', 'in', 'which']]
# 选项 [['direct'], ['familiar'], ['strange'], ['funny']]
# ---------8---------
# predict: A ground truth: A
# 空前后的词 [['waiter', 'and', 'i'], ['each', 'other', '<s>']]
# 选项 [['chatted', 'with'], ['looked', 'at'], ['laughed', 'at'], ['talked', 'about']]
# ---------9---------
# predict: B ground truth: B
# 空前后的词 [['more', 'puzzled', 'as'], ['went', 'on', 'and']]
# 选项 [['the', 'waiter'], ['time'], ['i'], ['the', 'dinner']]
# ---------10---------
# predict: C ground truth: C
# 空前后的词 [['and', 'it', 'became'], ['that', 'all', 'the']]
# 选项 [['true'], ['hopeful'], ['clear'], ['possible']]
# ---------11---------
# predict: D ground truth: D
# 空前后的词 [['went', 'into', 'the'], ['<s>', '<s>', '<s>']]
# 选项 [['restaurant'], ['washroom'], ['office'], ['kitchen']]
# ---------12---------
# predict: A ground truth: A
# 空前后的词 [['his', 'bill', 'and'], ['without', 'another', 'glance']]
# 选项 [['left'], ['acted'], ['sat', 'down'], ['calmed', 'down']]
# ---------13---------
# predict: A ground truth: A
# 空前后的词 [['the', 'man', 'had'], ['<s>', '<s>', '<s>']]
# 选项 [['wanted'], ['tried'], ['ordered'], ['wished']]
# ---------14---------
# predict: A ground truth: C
# 空前后的词 [['<s>', '<s>', 'he'], ['you', 'here', 'because']]
# 选项 [['met'], ['caught'], ['followed'], ['discovered']]
# ---------15---------
# predict: A ground truth: D
# 空前后的词 [['the', 'man', 'he'], ['<s>', '<s>', '<s>']]
# 选项 [['was', 'to', 'beat'], ['was', 'dealing', 'with'], ['was', 'to', 'meet'], ['was', 'looking', 'for']]
# ---------16---------
# predict: A ground truth: B
# 空前后的词 [['<s>', 'showing', 'my'], ['<s>', '<s>', '<s>']]
# 选项 [['care'], ['surprise'], ['worry'], ['regret']]
# ---------17---------
# predict: B ground truth: A
# 空前后的词 [['<s>', '<s>', 'i'], ['say', 'he', 'looked']]
# 选项 [['must'], ['can'], ['need'], ['may']]
# ---------18---------
# predict: B ground truth: B
# 空前后的词 [['had', 'made', 'a'], ['<s>', '<s>', '<s>']]
# 选项 [['discovery'], ['mistake'], ['decision'], ['fortune']]
# ---------19---------
# predict: A ground truth: D
# 空前后的词 [['<s>', "it's", 'really'], ['i', 'came', 'to']]
# 选项 [['a', 'pity'], ['natural'], ['a', 'chance'], ['lucky']]
# ---------20---------
# predict: B ground truth: C
# 空前后的词 [['<s>', '<s>', '<s>'], ['<s>', '<s>', '<s>']]
# 选项 [['thus'], ['however'], ['otherwise'], ['therefore']]
# ---------1---------
# predict: A ground truth: B
# 空前后的词 [['<s>', '<s>', 'i'], ['the', 'idea', 'of']]
# 选项 [['put', 'forward'], ['jumped', 'at'], ['tried', 'out'], ['turned', 'down']]
# ---------2---------
# predict: B ground truth: C
# 空前后的词 [["doesn't", 'want', 'to'], ['a', 'few', 'dollars']]
# 选项 [['waste'], ['earn'], ['save'], ['pay']]
# ---------3---------
# predict: A ground truth: A
# 空前后的词 [['if', 'i', "weren't"], ['enough', 'about', 'free']]
# 选项 [['excited'], ['worried'], ['moved'], ['tired']]
# ---------4---------
# predict: A ground truth: D
# 空前后的词 [['news', 'about', 'our'], ['was', 'appealing', 'enough']]
# 选项 [['title'], ['competitor'], ['textbook'], ['instructor']]
# ---------5---------
# predict: D ground truth: D
# 空前后的词 [['<s>', '<s>', 'which'], ['i', 'would', 'be']]
# 选项 [['urged'], ['demanded'], ['held'], ['meant']]
# ---------6---------
# predict: A ground truth: C
# 空前后的词 [['of', 'the', "game's"], ['<s>', '<s>', '<s>']]
# 选项 [['fastest'], ['easiest'], ['best'], ['rarest']]
# ---------7---------
# predict: B ground truth: B
# 空前后的词 [['hardly', 'wait', 'to'], ['him', '<s>', '<s>']]
# 选项 [['interview'], ['meet'], ['challenge'], ['beat']]
# ---------8---------
# predict: A ground truth: D
# 空前后的词 [['<s>', 'and', 'this'], ['was', 'no', 'game']]
# 选项 [['chance'], ['qualification'], ['honor'], ['job']]
# ---------9---------
# predict: C ground truth: C
# 空前后的词 [['he', 'made', 'it'], ['that', 'our', 'credits']]
# 选项 [['real'], ['perfect'], ['clear'], ['possible']]
# ---------10---------
# predict: A ground truth: B
# 空前后的词 [['in', 'order', 'to'], ['the', 'class', '<s>']]
# 选项 [['attend'], ['pass'], ['skip'], ['observe']]
# ---------11---------
# predict: A ground truth: C
# 空前后的词 [['we', 'plan', 'to'], ['what', 'we', 'would']]
# 选项 [['add'], ['expose'], ['apply'], ['compare']]
# ---------12---------
# predict: A ground truth: A
# 空前后的词 [['<s>', '<s>', '<s>'], ['<s>', '<s>', '<s>']]
# 选项 [['eventually'], ['naturally'], ['directly'], ['normally']]
# ---------13---------
# predict: A ground truth: C
# 空前后的词 [['a', 'in', 'that'], ['and', 'learned', 'life']]
# 选项 [['game'], ['presentation'], ['course'], ['experiment']]
# ---------14---------
# predict: B ground truth: B
# 空前后的词 [['well', 'beyond', 'the'], ['<s>', '<s>', '<s>']]
# 选项 [['criterion'], ['classroom'], ['department'], ['situation']]
# ---------15---------
# predict: A ground truth: A
# 空前后的词 [['use', 'what', 'he'], ['me', ':the', 'absolute']]
# 选项 [['taught'], ['wrote'], ['questioned'], ['promised']]
# ---------16---------
# predict: A ground truth: D
# 空前后的词 [['absolute', 'most', 'important'], ['that', 'you', 'learn']]
# 选项 [['fact'], ['step'], ['manner'], ['skill']]
# ---------17---------
# predict: B ground truth: B
# 空前后的词 [['to', 'make', 'good'], ['<s>', '<s>', '<s>']]
# 选项 [['grades'], ['decisions'], ['impressions'], ['comments']]
# ---------18---------
# predict: B ground truth: A
# 空前后的词 [['you', 'have', 'to'], ['a', 'situation', '<s>']]
# 选项 [['analyze'], ['describe'], ['rebuild'], ['control']]
# ---------19---------
# predict: A ground truth: D
# 空前后的词 [['is', 'doing', 'and'], ['the', 'best', 'move']]
# 选项 [['announce'], ['signal'], ['block'], ['evaluate']]
# ---------20---------
# predict: A ground truth: A
# 空前后的词 [['today', 'in', 'my'], ['as', 'a', 'journalist']]
# 选项 [['role'], ['desire'], ['concern'], ['behavior']]
# accuracy: 0.5

# %%
test(content_list,options_list,answers_list,N,showAll=False)
# Out:
# ---------2---------
# predict: A ground truth: A
# 空前后的词 [['so', 'imagine', 'my'], ['when', 'he', 'emailed']]
# 选项 [['delight'], ['relief'], ['anger'], ['worry']]
# ---------5---------
# predict: A ground truth: A
# 空前后的词 [['the', 'bay', 'was'], ['in', 'sunshine', '<s>']]
# 选项 [['bathed'], ['clean'], ['deep'], ['formed']]
# ---------7---------
# predict: A ground truth: A
# 空前后的词 [['kayak', 'was', 'in'], ['<s>', '<s>', '<s>']]
# 选项 [['trouble'], ['advance'], ['question'], ['battle']]
# ---------10---------
# predict: D ground truth: D
# 空前后的词 [['<s>', 'he', 'was'], ['violently', '<s>', '<s>']]
# 选项 [['arguing'], ['fighting'], ['shouting'], ['shaking']]
# ---------13---------
# predict: D ground truth: D
# 空前后的词 [['eyes', 'were', 'very'], ['<s>', '<s>', '<s>']]
# 选项 [['sharp'], ['pleasant'], ['attractive'], ['familiar']]
# ---------15---------
# predict: A ground truth: A
# 空前后的词 [['<s>', '<s>', '<s>'], ['<s>', '<s>', '<s>']]
# 选项 [['fortunately'], ['frankly'], ['sadly'], ['suddenly']]
# ---------16---------
# predict: D ground truth: D
# 空前后的词 [['be', 'allowed', 'to'], ['and', 'later', 'the']]
# 选项 [['return'], ['relax'], ['speak'], ['leave']]
# ---------17---------
# predict: B ground truth: B
# 空前后的词 [['and', 'then', 'ben'], ['to', 'me', '<s>']]
# 选项 [['joked'], ['turned'], ['listened'], ['pointed']]
# ---------18---------
# predict: C ground truth: C
# 空前后的词 [['<s>', '<s>', 'you'], ['my', 'life', '<s>']]
# 选项 [['created'], ['honored'], ['saved'], ['guided']]
# ---------20---------
# predict: B ground truth: B
# 空前后的词 [['i', 'was', 'there'], ['to', 'help', 'my']]
# 选项 [['on', 'board'], ['in', 'time'], ['for', 'sure'], ['on', 'purpose']]
# ---------1---------
# predict: C ground truth: C
# 空前后的词 [['<s>', 'suddenly', 'i'], ['that', 'a', 'man']]
# 选项 [['knew'], ['understood'], ['noticed'], ['recognized']]
# ---------2---------
# predict: D ground truth: D
# 空前后的词 [['<s>', '<s>', '<s>'], ['he', 'knew', 'me']]
# 选项 [['since'], ['even', 'if'], ['though'], ['as', 'if']]
# ---------4---------
# predict: C ground truth: C
# 空前后的词 [['which', 'he', 'was'], ['to', 'read', '<s>']]
# 选项 [['hoping'], ['thinking'], ['pretending'], ['continuing']]
# ---------5---------
# predict: A ground truth: A
# 空前后的词 [['but', 'i', 'could'], ['that', 'he', 'was']]
# 选项 [['see'], ['find'], ['guess'], ['learn']]
# ---------8---------
# predict: A ground truth: A
# 空前后的词 [['waiter', 'and', 'i'], ['each', 'other', '<s>']]
# 选项 [['chatted', 'with'], ['looked', 'at'], ['laughed', 'at'], ['talked', 'about']]
# ---------9---------
# predict: B ground truth: B
# 空前后的词 [['more', 'puzzled', 'as'], ['went', 'on', 'and']]
# 选项 [['the', 'waiter'], ['time'], ['i'], ['the', 'dinner']]
# ---------10---------
# predict: C ground truth: C
# 空前后的词 [['and', 'it', 'became'], ['that', 'all', 'the']]
# 选项 [['true'], ['hopeful'], ['clear'], ['possible']]
# ---------11---------
# predict: D ground truth: D
# 空前后的词 [['went', 'into', 'the'], ['<s>', '<s>', '<s>']]
# 选项 [['restaurant'], ['washroom'], ['office'], ['kitchen']]
# ---------12---------
# predict: A ground truth: A
# 空前后的词 [['his', 'bill', 'and'], ['without', 'another', 'glance']]
# 选项 [['left'], ['acted'], ['sat', 'down'], ['calmed', 'down']]
# ---------13---------
# predict: A ground truth: A
# 空前后的词 [['the', 'man', 'had'], ['<s>', '<s>', '<s>']]
# 选项 [['wanted'], ['tried'], ['ordered'], ['wished']]
# ---------18---------
# predict: B ground truth: B
# 空前后的词 [['had', 'made', 'a'], ['<s>', '<s>', '<s>']]
# 选项 [['discovery'], ['mistake'], ['decision'], ['fortune']]
# ---------3---------
# predict: A ground truth: A
# 空前后的词 [['if', 'i', "weren't"], ['enough', 'about', 'free']]
# 选项 [['excited'], ['worried'], ['moved'], ['tired']]
# ---------5---------
# predict: D ground truth: D
# 空前后的词 [['<s>', '<s>', 'which'], ['i', 'would', 'be']]
# 选项 [['urged'], ['demanded'], ['held'], ['meant']]
# ---------7---------
# predict: B ground truth: B
# 空前后的词 [['hardly', 'wait', 'to'], ['him', '<s>', '<s>']]
# 选项 [['interview'], ['meet'], ['challenge'], ['beat']]
# ---------9---------
# predict: C ground truth: C
# 空前后的词 [['he', 'made', 'it'], ['that', 'our', 'credits']]
# 选项 [['real'], ['perfect'], ['clear'], ['possible']]
# ---------12---------
# predict: A ground truth: A
# 空前后的词 [['<s>', '<s>', '<s>'], ['<s>', '<s>', '<s>']]
# 选项 [['eventually'], ['naturally'], ['directly'], ['normally']]
# ---------14---------
# predict: B ground truth: B
# 空前后的词 [['well', 'beyond', 'the'], ['<s>', '<s>', '<s>']]
# 选项 [['criterion'], ['classroom'], ['department'], ['situation']]
# ---------15---------
# predict: A ground truth: A
# 空前后的词 [['use', 'what', 'he'], ['me', ':the', 'absolute']]
# 选项 [['taught'], ['wrote'], ['questioned'], ['promised']]
# ---------17---------
# predict: B ground truth: B
# 空前后的词 [['to', 'make', 'good'], ['<s>', '<s>', '<s>']]
# 选项 [['grades'], ['decisions'], ['impressions'], ['comments']]
# ---------20---------
# predict: A ground truth: A
# 空前后的词 [['today', 'in', 'my'], ['as', 'a', 'journalist']]
# 选项 [['role'], ['desire'], ['concern'], ['behavior']]
# accuracy: 0.5
